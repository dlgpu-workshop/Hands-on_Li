# %%
import os
import torch
import numpy as np
import matplotlib.pyplot as plt
import imageio
import torchvision.transforms.functional as F


plt.rcParams["savefig.bbox"] = 'tight'


def show(imgs):
    if not isinstance(imgs, list):
        imgs = [imgs]
    fig, axs = plt.subplots(ncols=len(imgs), squeeze=False)
    for i, img in enumerate(imgs):
        img = img.detach()
        img = F.to_pil_image(img)
        axs[0, i].imshow(np.asarray(img))
        axs[0, i].set(xticklabels=[], yticklabels=[], xticks=[], yticks=[])

# %%
from torchvision.utils import make_grid
from torchvision.io import read_image
from pathlib import Path

# %%
dog1_int = imageio.imread(str(Path('assets') / r"C:\Users\mikeb\Desktop\Test\1.tif"))
dog2_int = imageio.imread(str(Path('assets') / r"C:\Users\mikeb\Desktop\Test\2.tif"))
dog1_tsr = torch.from_numpy(dog1_int).unsqueeze(0).float()
dog2_tsr = torch.from_numpy(dog2_int).unsqueeze(0).float()
dog_list = [dog1_tsr, dog2_tsr]

grid = make_grid(dog_list)
show(grid)
# Out:
# C:\Users\mikeb\AppData\Local\Temp\ipykernel_30944\2018073328.py:1: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   dog1_int = imageio.imread(str(Path('assets') / r"C:\Users\mikeb\Desktop\Test\1.tif"))
# C:\Users\mikeb\AppData\Local\Temp\ipykernel_30944\2018073328.py:2: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   dog2_int = imageio.imread(str(Path('assets') / r"C:\Users\mikeb\Desktop\Test\2.tif"))

# %%
import matplotlib.pyplot as plt
import imageio
from pathlib import Path

img_path = str(Path('assets') / r"C:\Users\mikeb\Desktop\Test\1.tif")
img = imageio.imread(img_path)
plt.imshow(img)
plt.axis('off')
plt.show()
# Out:
# C:\Users\mikeb\AppData\Local\Temp\ipykernel_30944\1445050942.py:6: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img = imageio.imread(img_path)

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
# load the model and the trained weights

# %%
from torchvision.models.detection import FasterRCNN
# Define the device to use (CPU or GPU)
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# Load your custom model
model = create_model(num_classes=NUM_CLASSES).to(device)

model.load_state_dict(torch.load(
        'C:/Users/mikeb/Projects/Pytorch/Pytorch/env/faster_rcnn_test-main/faster_rcnn_test-main/outputs/model'+str(NUM_EPOCHS)+'.pth', map_location=device
    ))
model.eval()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 2
#       1 from torchvision.models.detection import FasterRCNN
# ----> 2 from my_custom_model import MyCustomModel
#       4 # Define the device to use (CPU or GPU)
#       5 device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
#
# ModuleNotFoundError: No module named 'my_custom_model'

# %%
# Define the transforms to apply to your images
transforms = ...

# Load your images and apply the transforms
images = [transforms(d) for d in dog_list]

# Make predictions using your model
outputs = model(images)

# Print the model's predictions
print(outputs)
